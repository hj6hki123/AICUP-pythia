# %% [markdown]
# | Coding Type | Precision | Recall | F-measure | Support |
# |-------------|----------:|:------:|----------:|--------:|
# | MEDICALRECORD | 0.7916667 | 0.9156626 | 0.849162 | 747 |
# | PATIENT | 0.88251 | 0.9231843 | 0.9023891 | 716 |
# | IDNUM | 0.9669421 | 0.8278302 | 0.8919949 | 2120 |
# | DATE | 0.952121 | 0.9219195 | 0.9367769 | 2459 |
# | DOCTOR | 0.9372043 | 0.6549444 | 0.7710545 | 3327 |
# | STREET | 0.9266409 | 0.6976744 | 0.79602 | 344 |
# | CITY | 0.9637883 | 0.9276139 | 0.9453552 | 373 |
# | STATE | 0.993921 | 0.9849398 | 0.98941 | 332 |
# | ZIP | 0.994302 | 0.9886686 | 0.9914773 | 353 |
# | DEPARTMENT | 0.8593351 | 0.8019093 | 0.8296297 | 419 |
# | HOSPITAL | 0.8558952 | 0.8180301 | 0.8365344 | 1198 |
# | DURATION | 0.5 | 0.1666667 | 0.25 | 12 |
# | TIME | 0.131579 | 0.0212766 | 0.03663004 | 470 |
# | AGE | 0.8571429 | 0.7058824 | 0.7741936 | 51 |
# | ORGANIZATION | 0.4565217 | 0.5675676 | 0.5060241 | 74 |
# | SET | 1 | 0.4 | 0.5714286 | 5 |
# | LOCATION-OTHER | 1 | 0.1666667 | 0.2857143 | 6 |
# | PHONE | 1 | 1 | 1 | 1 |
# | Micro-avg. F| 0.9134632 | 0.785577 | 0.8447071 | 13007 |
# | Macro-avg. F| 0.8371984 | 0.6939132 | 0.7588513 | 13007 |
# |-------------|----------:|:------:|----------:|----------:|
# |-------------|----------:|:------:|----------:|----------:|
# | Temporal Type | Precision | Recall | F-measure | Support |
# |-------------|----------:|:------:|----------:|----------:|
# | DATE | 0.8151742 | 0.751525 | 0.7820567 | 2459 |
# | DURATION | 0.5 | 0.08333334 | 0.1428571 | 12 |
# | TIME | 0 | 0 | 0 | 470 |
# | SET | 1 | 0.4 | 0.5714286 | 5 |
# | Micro-avg.| 0.8114862 | 0.6283095 | 0.7082456 | 2946 |
# | Macro-avg.| 0.5787935 | 0.3087146 | 0.40266 | 2946 |
# |-------------|----------:|:------:|----------:|----------:|
